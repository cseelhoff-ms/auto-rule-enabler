# %% [markdown]
# # Import and convert Neo23x0 Sigma scripts
# ianhelle@microsoft.com
#
# This notebook is a is a quick and dirty Sigma to Log Analytics converter.
# It uses the modules from sigmac package to do the conversion.
#
# Only a subset of the Sigma rules are convertible currently. Failure to convert
# could be for one or more of these reasons:
# - known limitations of the converter
# - mismatch between the syntax expressible in Sigma and KQL
# - data sources referenced in Sigma rules do not yet exist in Microsoft Sentinel
#
# The sigmac tool is downloadable as a package from PyPi but since we are downloading
# the rules from the repo, we also copy and import the package from the repo source.
#
# After conversion you can use an interactive browser to step through the rules and
# view (and copy/save) the KQL equivalents. You can also take the conversion results and
# use them in another way (e.g.bulk save to files).
#
# The notebook is all somewhat experimental and offered as-is without any guarantees

# %% [markdown]
# ## Download and unzip the Sigma repo

# %%
from pathlib import Path
from IPython.display import display, HTML

REQ_PYTHON_VER = "3.6"
REQ_MSTICPY_VER = "1.0.0"

display(HTML("<h3>Starting Notebook setup...</h3>"))

# If not using Azure Notebooks, install msticpy with
# %pip install msticpy

from msticpy.nbtools import nbinit
nbinit.init_notebook(namespace=globals());
# Out:
# <h3>Starting Notebook setup...</h3>

# %%
import requests
# Download the repo ZIP
sigma_git_url = 'https://github.com/Neo23x0/sigma/archive/master.zip'
r = requests.get(sigma_git_url)

# %%
from ipywidgets import widgets, Layout
import os
from pathlib import Path
def_path = Path.joinpath(Path(os.getcwd()), "./")
path_wgt = widgets.Text(value=str(def_path), 
                        description='Path to extract to zipped repo files: ', 
                        layout=Layout(width='50%'),
                        style={'description_width': 'initial'})
path_wgt
# Out:
# Text(value='c:\\Users\\cseelhoff\\source\\repos\\auto-rule-enabler', description='Path to extract to zipped re…

# %%
RULES_REL_PATH = 'sigma-master/rules'
rules_root = Path(path_wgt.value) / RULES_REL_PATH

# %% [markdown]
# Note that this can take some time to complete

# %%
import zipfile
import io
repo_zip = io.BytesIO(r.content)

zip_archive = zipfile.ZipFile(repo_zip, mode='r')
zip_archive.extractall(path=path_wgt.value)

# %% [markdown]
# ### Check that we have the files
# You should see a folder with folders such as application, apt, windows...

# %%
# %ls {rules_root}
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 0A26-8564
#
#  Directory of c:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules
#
# 09/14/2023  10:48 AM    <DIR>          .
# 10/26/2023  10:51 AM    <DIR>          ..
# 09/14/2023  10:48 AM    <DIR>          application
# 09/14/2023  10:48 AM    <DIR>          category
# 09/14/2023  10:48 AM    <DIR>          cloud
# 09/14/2023  10:48 AM    <DIR>          compliance
# 09/14/2023  10:48 AM    <DIR>          linux
# 09/14/2023  10:48 AM    <DIR>          macos
# 09/14/2023  10:48 AM    <DIR>          network
# 10/26/2023  10:51 AM                 3 README.md
# 09/14/2023  10:48 AM    <DIR>          web
# 10/09/2023  11:51 AM    <DIR>          windows
#                1 File(s)              3 bytes
#               11 Dir(s)  495,966,023,680 bytes free

# %% [markdown]
# ## Convert Sigma Files to Log Analytics Kql queries

# %%
# Read the Sigma YAML file paths into a dict and make a
# a copy for the target Kql queries
from pathlib import Path
from collections import defaultdict
import copy

def get_rule_files(rules_root):
    file_dict = defaultdict(dict)
    for file in Path(rules_root).resolve().rglob("*.yml"):
        rel_path = Path(file).relative_to(rules_root)
        path_key = '.'.join(rel_path.parent.parts)
        file_dict[path_key][rel_path.name] = file
    return file_dict
    
sigma_dict = get_rule_files(rules_root)
kql_dict = copy.deepcopy(sigma_dict)

# %%
# Add downloaded sigmac tool to sys.path and import Sigmac functions
import os
import sys
module_path = os.path.abspath(os.path.join('sigma/sigma-master/tools'))
if module_path not in sys.path:
    sys.path.append(module_path)
from sigma.parser.collection import SigmaCollectionParser
from sigma.parser.exceptions import SigmaCollectionParseError, SigmaParseError
from sigma.configuration import SigmaConfiguration, SigmaConfigurationChain
from sigma.config.exceptions import SigmaConfigParseError, SigmaRuleFilterParseException
from sigma.filter import SigmaRuleFilter
import sigma.backends.discovery as backends
from sigma.backends.base import BackendOptions
from sigma.backends.exceptions import BackendError, NotSupportedError, PartialMatchError, FullMatchError

# %%
# Sigma to Log Analytics Conversion
import yaml
_LA_MAPPINGS = '''
fieldmappings:
  Image: NewProcessName
  ParentImage: ParentProcessName
  ParentCommandLine: NO_MAPPING
'''

NOT_CONVERTIBLE = 'Not convertible'

def sigma_to_la(file_path):
    with open(file_path, 'r') as input_file:
        try:
            sigmaconfigs = SigmaConfigurationChain()
            sigmaconfig = SigmaConfiguration(_LA_MAPPINGS)
            sigmaconfigs.append(sigmaconfig)
            backend_options = BackendOptions(None, None)
            backend = backends.getBackend('ala')(sigmaconfigs, backend_options)
            parser = SigmaCollectionParser(input_file, sigmaconfigs, None)
            results = parser.generate(backend)
            kql_result = ''
            for result in results:
                kql_result += result
        except (NotImplementedError, NotSupportedError, TypeError):
            kql_result = NOT_CONVERTIBLE
        input_file.seek(0,0)
        sigma_txt = input_file.read()
        if not kql_result == NOT_CONVERTIBLE:
            try:
                kql_header = "\n".join(get_sigma_properties(sigma_txt))
                kql_result = kql_header + "\n" + kql_result
            except Exception as e:
                print("exception reading sigma YAML: ", e)
                print(sigma_txt, kql_result, sep='\n')
        return sigma_txt, kql_result

sigma_keys = ['title', 'description', 'tags', 'status', 
              'author', 'logsource', 'falsepositives', 'level']

def get_sigma_properties(sigma_rule):
    sigma_docs = yaml.load_all(sigma_rule, Loader=yaml.SafeLoader)
    sigma_rule_dict = next(sigma_docs)
    for prop in sigma_keys:
        yield get_property(prop, sigma_rule_dict)

def get_property(name, sigma_rule_dict):
    sig_prop = sigma_rule_dict.get(name, 'na')
    if isinstance(sig_prop, dict):
        sig_prop = ' '.join([f"{k}: {v}" for k, v in sig_prop.items()])
    return f"// {name}: {sig_prop}"
        
   
_KQL_FILTERS = {
    'date': ' | where TimeGenerated >= datetime({start}) and TimeGenerated <= datetime({end}) ',
    'host': ' | where Computer has {host_name} '
}

def insert_at(source, insert, find_sub):
    pos = source.find(find_sub)
    if pos != -1:
        return source[:pos] + insert + source[pos:]
    else:
        return source + insert
        
def add_filter_clauses(source, **kwargs):
    if "{" in source or "}" in source:
        source = ("// Warning: embedded braces in source. Please edit if necessary.\n"
                  + source)
        source = source.replace('{', '{{').replace('}', '}}')
    if kwargs.get('host', False):
        source = insert_at(source, _KQL_FILTERS['host'], '|')
    if kwargs.get('date', False):
        source = insert_at(source, _KQL_FILTERS['date'], '|')
    return source

# create new list of rules that failed to convert
failed_rules = []

# Run the conversion
print("Converting rules")
conv_counter = {}
for categ, sources in sigma_dict.items():
    src_converted = 0
    print("\n", categ, end="")
    for file_name, file_path in sources.items():
        try:
            sigma, kql = sigma_to_la(file_path)
            print(".", end="")
        except:
            print(f"Error converting {file_name} ({file_path})")
            failed_rules.append(file_path)
            continue
        kql_dict[categ][file_name] = (sigma, kql)
        if not kql == NOT_CONVERTIBLE:
            src_converted += 1
    conv_counter[categ] = (len(sources), src_converted)

print("\nConversion statistics")
print("-" * len("Conversion statistics"))
print('\n'.join([f'{categ}: rules: {counter[0]}, converted: {counter[1]}'
                 for categ, counter in conv_counter.items()]))

# save the list of failed rules
with open('failed_rules.txt', 'w') as f:
    f.write('\n'.join([str(rule) for rule in failed_rules]))
# Out:
# Converting rules
#
#  application.django.
#  application.jvm.....
#  application.nodejs.
#  application.python.
#  application.rpc_firewall.................
#  application.ruby.
#  application.spring..
#  application.sql.
#  application.velocity.
#  category.antivirus.......
#  category.database.
#  cloud.aws.................................
#  cloud.aws.cloudtrail.................................
#  cloud.azure....................................................................................................
#  cloud.azure.activity_logs...........................................
#  cloud.azure.audit_logs.................................
#  cloud.azure.identity_protection...................
#  cloud.azure.privileged_identity_management.......
#  cloud.azure.signin_logs........................
#  cloud.gcp..............
#  cloud.gcp.audit..............
#  cloud.gcp.gworkspace......
#  cloud.github.......
#  cloud.gworkspace......
#  cloud.m365..................
#  cloud.m365.audit..
#  cloud.m365.exchange.
#  cloud.m365.threat_detection.
#  cloud.m365.threat_management.............
#  cloud.okta...................
#  cloud.onelogin..
#  compliance...
#  linux.auditd.................................................
#  linux.builtin.................
#  linux.builtin.auth.
#  linux.builtin.clamav.
#  linux.builtin.cron.
#  linux.builtin.guacamole.
#  linux.builtin.sshd..
#  linux.builtin.sudo.
#  linux.builtin.syslog..
#  linux.builtin.vsftpd.
#  linux.file_event.......
#  linux.network_connection...
#  linux.process_creation....................................................................................................
#  macos.file_event..
#  macos.process_creation.................................................
#  network.cisco.aaa............
#  network.cisco.bgp.
#  network.cisco.ldp.
#  network.dns.......
#  network.firewall..
#  network.huawei.bgp.
#  network.juniper.bgp.
#  network.zeek.....................
#  web.product.apache..
#  web.product.nginx.
#  web.proxy_generic......................................Error converting proxy_webdav_search_ms.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\web\proxy_generic\proxy_webdav_search_ms.yml)
#
#  web.webserver_generic............
#  windows.builtin.
#  windows.builtin.application.application_error..
#  windows.builtin.application.esent..
#  windows.builtin.application.microsoft-windows_audit_cve.
#  windows.builtin.application.microsoft_windows_backup.
#  windows.builtin.application.microsoft_windows_software_restriction_policies.
#  windows.builtin.application.msexchange_control_panel.
#  windows.builtin.application.msiinstaller.....
#  windows.builtin.application.msmq.
#  windows.builtin.application.mssqlserver........
#  windows.builtin.application.Other.
#  windows.builtin.application.screenconnect..
#  windows.builtin.application.windows_error_reporting.
#  windows.builtin.applocker.
#  windows.builtin.appmodel_runtime.
#  windows.builtin.appxdeployment_server.......
#  windows.builtin.appxpackaging_om.
#  windows.builtin.bits_client.......
#  windows.builtin.capi2.
#  windows.builtin.certificate_services_client_lifecycle_system.
#  windows.builtin.code_integrity..........
#  windows.builtin.diagnosis.scripted.
#  windows.builtin.dns_client.....
#  windows.builtin.dns_server..
#  windows.builtin.dns_server_analytic.
#  windows.builtin.driverframeworks.
#  windows.builtin.firewall_as........
#  windows.builtin.ldap.
#  windows.builtin.lsa_server.
#  windows.builtin.msexchange........
#  windows.builtin.ntlm...
#  windows.builtin.openssh.
#  windows.builtin.security.........................................................................................................................
#  windows.builtin.security.account_management...........Error converting win_security_successful_external_remote_rdp_login.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\builtin\security\account_management\win_security_successful_external_remote_rdp_login.yml)
# Error converting win_security_successful_external_remote_smb_login.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\builtin\security\account_management\win_security_successful_external_remote_smb_login.yml)
# .....
#  windows.builtin.security_mitigations..
#  windows.builtin.servicebus.
#  windows.builtin.shell_core.
#  windows.builtin.smbclient.security.
#  windows.builtin.system.application_popup.
#  windows.builtin.system.lsasrv.
#  windows.builtin.system.microsoft_windows_dhcp_server..
#  windows.builtin.system.microsoft_windows_directory_services_sam.
#  windows.builtin.system.microsoft_windows_distributed_com.
#  windows.builtin.system.microsoft_windows_eventlog..
#  windows.builtin.system.microsoft_windows_kerberos_key_distribution_center..
#  windows.builtin.system.microsoft_windows_kernel_general..
#  windows.builtin.system.microsoft_windows_ntfs.
#  windows.builtin.system.microsoft_windows_user_profiles_service.
#  windows.builtin.system.microsoft_windows_windows_update_client.
#  windows.builtin.system.netlogon..
#  windows.builtin.system.ntfs.
#  windows.builtin.system.service_control_manager....Error converting win_system_defender_disabled.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\builtin\system\service_control_manager\win_system_defender_disabled.yml)
# ...........................................
#  windows.builtin.system.termdd.
#  windows.builtin.taskscheduler...
#  windows.builtin.terminalservices.
#  windows.builtin.windefend..Error converting win_defender_disabled.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\builtin\windefend\win_defender_disabled.yml)
# ........Error converting win_defender_threat.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\builtin\windefend\win_defender_threat.yml)
#
#  windows.builtin.wmi.
#  windows.create_remote_thread............
#  windows.create_stream_hash.........
#  windows.dns_query...................
#  windows.driver_load..................
#  windows.file.file_access.......
#  windows.file.file_change..
#  windows.file.file_delete............
#  windows.file.file_event............................................Error converting file_event_win_iphlpapi_dll_sideloading.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\file\file_event\file_event_win_iphlpapi_dll_sideloading.yml)
# ...................................................................Error converting file_event_win_susp_homoglyph_filename.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\file\file_event\file_event_win_susp_homoglyph_filename.yml)
# ............................................
#  windows.file.file_rename..
#  windows.image_load...............................................................................................
#  windows.network_connection............................................
#  windows.pipe_created..................
#  windows.powershell.powershell_classic...............
#  windows.powershell.powershell_module................................
#  windows.powershell.powershell_script..................................Error converting posh_ps_etw_trace_evasion.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\powershell\powershell_script\posh_ps_etw_trace_evasion.yml)
# ................................................................................................................................
#  windows.process_access...........................
#  windows.process_creation...................................................................................................Error converting proc_creation_win_csi_execution.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_csi_execution.yml)
# .......................................................................................................................................................Error converting proc_creation_win_homoglyph_cyrillic_lookalikes.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_homoglyph_cyrillic_lookalikes.yml)
# .............................................................................................................................................................................Error converting proc_creation_win_net_default_accounts_manipulation.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_net_default_accounts_manipulation.yml)
# .....................................................................................................................................................................................................................................................Error converting proc_creation_win_remote_access_tools_anydesk_silent_install.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_remote_access_tools_anydesk_silent_install.yml)
# .............................................................................................................................................Error converting proc_creation_win_susp_child_process_as_system_.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_susp_child_process_as_system_.yml)
# .Error converting proc_creation_win_susp_cli_obfuscation_unicode.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_susp_cli_obfuscation_unicode.yml)
# ..................Error converting proc_creation_win_susp_etw_trace_evasion.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\process_creation\proc_creation_win_susp_etw_trace_evasion.yml)
# .....................................................................................................................................................................................................................
#  windows.process_tampering.
#  windows.raw_access_thread.
#  windows.registry.registry_add.........
#  windows.registry.registry_delete......
#  windows.registry.registry_event.....................................
#  windows.registry.registry_set........................................................Error converting registry_set_disable_windows_defender_service.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\registry\registry_set\registry_set_disable_windows_defender_service.yml)
# ...............................................................................................................Error converting registry_set_windows_defender_tamper.yml (C:\Users\cseelhoff\source\repos\auto-rule-enabler\sigma-master\rules\windows\registry\registry_set\registry_set_windows_defender_tamper.yml)
# ....
#  windows.sysmon.........
#  windows.wmi_event...
# Conversion statistics
# ---------------------
# application.django: rules: 1, converted: 0
# application.jvm: rules: 5, converted: 1
# application.nodejs: rules: 1, converted: 0
# application.python: rules: 1, converted: 0
# application.rpc_firewall: rules: 17, converted: 17
# application.ruby: rules: 1, converted: 0
# application.spring: rules: 2, converted: 0
# application.sql: rules: 1, converted: 0
# application.velocity: rules: 1, converted: 0
# category.antivirus: rules: 7, converted: 6
# category.database: rules: 1, converted: 0
# cloud.aws: rules: 33, converted: 33
# cloud.aws.cloudtrail: rules: 33, converted: 33
# cloud.azure: rules: 100, converted: 96
# cloud.azure.activity_logs: rules: 43, converted: 40
# cloud.azure.audit_logs: rules: 33, converted: 32
# cloud.azure.identity_protection: rules: 19, converted: 19
# cloud.azure.privileged_identity_management: rules: 7, converted: 7
# cloud.azure.signin_logs: rules: 24, converted: 24
# cloud.gcp: rules: 14, converted: 14
# cloud.gcp.audit: rules: 14, converted: 14
# cloud.gcp.gworkspace: rules: 6, converted: 6
# cloud.github: rules: 7, converted: 7
# cloud.gworkspace: rules: 6, converted: 6
# cloud.m365: rules: 18, converted: 18
# cloud.m365.audit: rules: 2, converted: 2
# cloud.m365.exchange: rules: 1, converted: 1
# cloud.m365.threat_detection: rules: 1, converted: 1
# cloud.m365.threat_management: rules: 13, converted: 13
# cloud.okta: rules: 19, converted: 19
# cloud.onelogin: rules: 2, converted: 2
# compliance: rules: 3, converted: 3
# linux.auditd: rules: 49, converted: 47
# linux.builtin: rules: 17, converted: 6
# linux.builtin.auth: rules: 1, converted: 0
# linux.builtin.clamav: rules: 1, converted: 0
# linux.builtin.cron: rules: 1, converted: 0
# linux.builtin.guacamole: rules: 1, converted: 1
# linux.builtin.sshd: rules: 2, converted: 0
# linux.builtin.sudo: rules: 1, converted: 1
# linux.builtin.syslog: rules: 2, converted: 0
# linux.builtin.vsftpd: rules: 1, converted: 0
# linux.file_event: rules: 7, converted: 7
# linux.network_connection: rules: 3, converted: 3
# linux.process_creation: rules: 100, converted: 100
# macos.file_event: rules: 2, converted: 2
# macos.process_creation: rules: 49, converted: 49
# network.cisco.aaa: rules: 12, converted: 0
# network.cisco.bgp: rules: 1, converted: 1
# network.cisco.ldp: rules: 1, converted: 1
# network.dns: rules: 7, converted: 7
# network.firewall: rules: 2, converted: 2
# network.huawei.bgp: rules: 1, converted: 1
# network.juniper.bgp: rules: 1, converted: 1
# network.zeek: rules: 21, converted: 21
# web.product.apache: rules: 2, converted: 0
# web.product.nginx: rules: 1, converted: 0
# web.proxy_generic: rules: 39, converted: 38
# web.webserver_generic: rules: 12, converted: 6
# windows.builtin: rules: 1, converted: 0
# windows.builtin.application.application_error: rules: 2, converted: 2
# windows.builtin.application.esent: rules: 2, converted: 2
# windows.builtin.application.microsoft-windows_audit_cve: rules: 1, converted: 1
# windows.builtin.application.microsoft_windows_backup: rules: 1, converted: 1
# windows.builtin.application.microsoft_windows_software_restriction_policies: rules: 1, converted: 1
# windows.builtin.application.msexchange_control_panel: rules: 1, converted: 1
# windows.builtin.application.msiinstaller: rules: 5, converted: 5
# windows.builtin.application.msmq: rules: 1, converted: 1
# windows.builtin.application.mssqlserver: rules: 8, converted: 8
# windows.builtin.application.Other: rules: 1, converted: 0
# windows.builtin.application.screenconnect: rules: 2, converted: 2
# windows.builtin.application.windows_error_reporting: rules: 1, converted: 1
# windows.builtin.applocker: rules: 1, converted: 1
# windows.builtin.appmodel_runtime: rules: 1, converted: 1
# windows.builtin.appxdeployment_server: rules: 7, converted: 7
# windows.builtin.appxpackaging_om: rules: 1, converted: 1
# windows.builtin.bits_client: rules: 7, converted: 7
# windows.builtin.capi2: rules: 1, converted: 1
# windows.builtin.certificate_services_client_lifecycle_system: rules: 1, converted: 1
# windows.builtin.code_integrity: rules: 10, converted: 10
# windows.builtin.diagnosis.scripted: rules: 1, converted: 1
# windows.builtin.dns_client: rules: 5, converted: 5
# windows.builtin.dns_server: rules: 2, converted: 2
# windows.builtin.dns_server_analytic: rules: 1, converted: 1
# windows.builtin.driverframeworks: rules: 1, converted: 1
# windows.builtin.firewall_as: rules: 8, converted: 8
# windows.builtin.ldap: rules: 1, converted: 1
# windows.builtin.lsa_server: rules: 1, converted: 1
# windows.builtin.msexchange: rules: 8, converted: 6
# windows.builtin.ntlm: rules: 3, converted: 3
# windows.builtin.openssh: rules: 1, converted: 1
# windows.builtin.security: rules: 121, converted: 121
# windows.builtin.security.account_management: rules: 18, converted: 16
# windows.builtin.security_mitigations: rules: 2, converted: 2
# windows.builtin.servicebus: rules: 1, converted: 0
# windows.builtin.shell_core: rules: 1, converted: 1
# windows.builtin.smbclient.security: rules: 1, converted: 1
# windows.builtin.system.application_popup: rules: 1, converted: 1
# windows.builtin.system.lsasrv: rules: 1, converted: 1
# windows.builtin.system.microsoft_windows_dhcp_server: rules: 2, converted: 2
# windows.builtin.system.microsoft_windows_directory_services_sam: rules: 1, converted: 1
# windows.builtin.system.microsoft_windows_distributed_com: rules: 1, converted: 1
# windows.builtin.system.microsoft_windows_eventlog: rules: 2, converted: 2
# windows.builtin.system.microsoft_windows_kerberos_key_distribution_center: rules: 2, converted: 2
# windows.builtin.system.microsoft_windows_kernel_general: rules: 2, converted: 2
# windows.builtin.system.microsoft_windows_ntfs: rules: 1, converted: 1
# windows.builtin.system.microsoft_windows_user_profiles_service: rules: 1, converted: 1
# windows.builtin.system.microsoft_windows_windows_update_client: rules: 1, converted: 1
# windows.builtin.system.netlogon: rules: 2, converted: 2
# windows.builtin.system.ntfs: rules: 1, converted: 1
# windows.builtin.system.service_control_manager: rules: 48, converted: 47
# windows.builtin.system.termdd: rules: 1, converted: 1
# windows.builtin.taskscheduler: rules: 3, converted: 3
# windows.builtin.terminalservices: rules: 1, converted: 1
# windows.builtin.windefend: rules: 12, converted: 10
# windows.builtin.wmi: rules: 1, converted: 1
# windows.create_remote_thread: rules: 12, converted: 12
# windows.create_stream_hash: rules: 9, converted: 9
# windows.dns_query: rules: 19, converted: 19
# windows.driver_load: rules: 18, converted: 18
# windows.file.file_access: rules: 7, converted: 7
# windows.file.file_change: rules: 2, converted: 2
# windows.file.file_delete: rules: 12, converted: 12
# windows.file.file_event: rules: 157, converted: 155
# windows.file.file_rename: rules: 2, converted: 2
# windows.image_load: rules: 95, converted: 95
# windows.network_connection: rules: 44, converted: 44
# windows.pipe_created: rules: 18, converted: 18
# windows.powershell.powershell_classic: rules: 15, converted: 15
# windows.powershell.powershell_module: rules: 32, converted: 32
# windows.powershell.powershell_script: rules: 163, converted: 162
# windows.process_access: rules: 27, converted: 27
# windows.process_creation: rules: 1048, converted: 1038
# windows.process_tampering: rules: 1, converted: 1
# windows.raw_access_thread: rules: 1, converted: 1
# windows.registry.registry_add: rules: 9, converted: 9
# windows.registry.registry_delete: rules: 6, converted: 6
# windows.registry.registry_event: rules: 37, converted: 37
# windows.registry.registry_set: rules: 173, converted: 171
# windows.sysmon: rules: 9, converted: 9
# windows.wmi_event: rules: 3, converted: 2

# %% [markdown]
# ## Display the results in an interactive browser
#
# > Note: in order to execute a query from the browser, run
# > the cells in the "Execute query" section first. Then
# > come back to the browser.

# %%
from ipywidgets import widgets, Layout

# Browser Functions
def on_cat_value_change(change):
    queries_w.options = kql_dict[change['new']].keys()
    queries_w.value = queries_w.options[0]

def on_query_value_change(change):
    if view_qry_check.value:
        qry_text = kql_dict[sub_cats_w.value][queries_w.value][1]
        if "Not convertible" not in qry_text:
            qry_text = add_filter_clauses(qry_text,
                                          date=add_date_filter_check.value,
                                          host=add_host_filter_check.value)
        query_text_w.value = qry_text.replace('|', '\n|')
        orig_text_w.value = kql_dict[sub_cats_w.value][queries_w.value][0]

def on_view_query_value_change(change):
    vis = 'visible' if view_qry_check.value else 'hidden'
    on_query_value_change(None)
    query_text_w.layout.visibility = vis
    orig_text_w.layout.visibility = vis

# Function defs for ExecuteQuery cell below
def click_exec_hqry(b):
    global qry_results
    query_name = queries_w.value
    query_cat = sub_cats_w.value
    query_text = query_text_w.value
    query_text = query_text.format(**qry_wgt.query_params)
    disp_results(query_text)

disp_result = None


def disp_results(query_text):
    if disp_result is None:
        print(
            "Cannot run query without authenticating.",
            "Please run subsequent cells first"
        )
        return
    disp_result.update("Running query...")
    qry_results = execute_kql_query(query_text)
    disp_result.update(qry_results)
        
exec_hqry_button = widgets.Button(description="Execute query..")

exec_hqry_button.on_click(click_exec_hqry)

# Browser widget setup
categories = list(sorted(kql_dict.keys()))
sub_cats_w = widgets.Select(options=categories, 
                              description='Category :   ',
                              layout=Layout(width='30%', height='120px'),
                              style = {'description_width': 'initial'})

queries_w = widgets.Select(options = kql_dict[categories[0]].keys(),
                           description='Query :    ',
                           layout=Layout(width='30%', height='120px'),
                           style = {'description_width': 'initial'})

query_text_w = widgets.Textarea(
    value='',
    description='Kql Query:',
    layout=Layout(width='100%', height='300px', visiblity='hidden'),
    disabled=False)
orig_text_w = widgets.Textarea(
    value='',
    description='Sigma Query:',
    layout=Layout(width='100%', height='250px', visiblity='hidden'),
    disabled=False)

query_text_w.layout.visibility = 'hidden'
orig_text_w.layout.visibility = 'hidden'
sub_cats_w.observe(on_cat_value_change, names='value')
queries_w.observe(on_query_value_change, names='value')

view_qry_check = widgets.Checkbox(description="View query", value=True)
add_date_filter_check = widgets.Checkbox(description="Add date filter", value=False)
add_host_filter_check = widgets.Checkbox(description="Add host filter", value=False)

view_qry_check.observe(on_view_query_value_change, names='value')
add_date_filter_check.observe(on_view_query_value_change, names='value')
add_host_filter_check.observe(on_view_query_value_change, names='value')
# view_qry_button.on_click(click_exec_hqry)
# display(exec_hqry_button);

vbox_opts = widgets.VBox([view_qry_check, add_date_filter_check, add_host_filter_check])
hbox = widgets.HBox([sub_cats_w, queries_w, vbox_opts])
vbox = widgets.VBox([hbox, orig_text_w, query_text_w])
on_view_query_value_change(None)
display(vbox)
# Out:
# VBox(children=(HBox(children=(Select(description='Category :   ', layout=Layout(height='120px', width='30%'), …

# %% [markdown]
# ## Click the `Execute query` button below to run the currently displayed query
# **Notes:**
# - To run the queries, first authenticate to Microsoft Sentinel
# - If you added a date filter to the query set the date range below in the control below

# %% [markdown]
# ### Authenticate to Microsoft Sentinel and Set Query Time bounds

# %%
from msticpy.nbtools.nbwidgets import QueryTime
from IPython.display import display
from msticpy.data import QueryProvider
from msticpy.common.wsconfig import WorkspaceConfig

ws_config = WorkspaceConfig()
qry_prov = QueryProvider("LogAnalytics")
#print(ws_config)
qry_prov.connect(ws_config.code_connect_str)

def clean_kql_comments(query_string):
    """Cleans"""
    import re
    return re.sub(r'(//[^\n]+)', '', query_string, re.MULTILINE).replace('\n', '').strip()

def execute_kql_query(query_string):
    if not query_string or len(query_string.strip()) == 0:
        print('No query supplied')
        return None
    src_query = clean_kql_comments(query_string)
    src_query = src_query.format(start=qry_wgt.start, end=qry_wgt.end)
    result = qry_prov.exec_query(src_query)
    
    return result

disp_result = display(display_id=True)

def exec_query_btn(btn):
    query = query_text_w.value
    result = execute_kql_query(query)
    disp_result.update(result)

exec_hqry_button = widgets.Button(description="Execute Query")
exec_hqry_button.on_click(exec_query_btn)

qry_wgt = QueryTime(units='days', before=5, after=0, max_before=30, max_after=10)

display(qry_wgt)
# Out:
# from connection string
# loganalytics://code().tenant('00ac9db9-508a-473b-aded-53250025bd24').workspace('85eaf31d-8e1d-4487-bacb-9149fd6aa198')
# 00ac9db9-508a-473b-aded-53250025bd24
# 85eaf31d-8e1d-4487-bacb-9149fd6aa198
# connected
# VBox(children=(HTML(value='<h4>Set query time boundaries</h4>'), HBox(children=(DatePicker(value=datetime.date…

# %% [markdown]
# ### Execute the Query

# %%
display(exec_hqry_button)
# Out:
# Button(description='Execute Query', style=ButtonStyle())

# %% [markdown]
# ## Save All Converted Files

# %%
path_save_wgt = widgets.Text(value=str(def_path) + "_kql_out",
                             description='Path to save KQL files: ',
                             layout=Layout(width='50%'),
                             style={'description_width': 'initial'})
path_save_wgt
# Out:
# Text(value='c:\\Users\\cseelhoff\\source\\repos\\auto-rule-enabler_kql_out', description='Path to save KQL fil…

# %%
root = Path(path_save_wgt.value)
root.mkdir(exist_ok=True)
for categ, kql_files in kql_dict.items():
    sub_dir = root.joinpath(categ)
    
    for file_name, contents in kql_files.items():
        try:
            kql_txt = contents[1]
            if not kql_txt == NOT_CONVERTIBLE:
                sub_dir.mkdir(exist_ok=True)
                file_path = sub_dir.joinpath(file_name.replace('.yml', '.kql'))
                with open(file_path, 'w') as output_file:
                    output_file.write(kql_txt)
                print(f"Saved {file_path}")
        except Exception as ex:
            print(f"Error saving {file_name} ({ex})")
            continue
# Out:
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.jvm\java_local_file_read.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_atsvc_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_atsvc_recon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_dcsync_attack.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_efs_abuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_eventlog_recon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_itaskschedulerservice_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_itaskschedulerservice_recon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_printing_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_remote_dcom_or_wmi.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_remote_registry_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_remote_registry_recon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_remote_server_service_abuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_remote_service_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_sasec_lateral_movement.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_sasec_recon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_sharphound_recon_account.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\application.rpc_firewall\rpc_firewall_sharphound_recon_sessions.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_exploiting.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_hacktool.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_password_dumper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_ransomware.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_relevant_files.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\category.antivirus\av_webshell.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_attached_malicious_lambda_layer.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_cloudtrail_disable_logging.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_config_disable_recording.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_delete_identity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_ec2_disable_encryption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_ec2_startup_script_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_ec2_vm_export_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_ecs_task_definition_cred_endpoint_query.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_efs_fileshare_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_efs_fileshare_mount_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_eks_cluster_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_elasticache_security_group_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_elasticache_security_group_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_enum_buckets.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_guardduty_disruption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_iam_backdoor_users_keys.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_iam_s3browser_loginprofile_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_iam_s3browser_templated_s3_bucket_policy_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_iam_s3browser_user_or_accesskey_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_passed_role_to_glue_development_endpoint.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_rds_change_master_password.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_rds_public_db_restore.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_root_account_usage.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_route_53_domain_transferred_lock_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_route_53_domain_transferred_to_another_account.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_s3_data_management_tampering.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_securityhub_finding_evasion.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_snapshot_backup_exfiltration.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_sso_idp_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_sts_assumerole_misuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_sts_getsessiontoken_misuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_susp_saml_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws\aws_update_login_profile.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_attached_malicious_lambda_layer.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_cloudtrail_disable_logging.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_config_disable_recording.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_delete_identity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_ec2_disable_encryption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_ec2_startup_script_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_ec2_vm_export_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_ecs_task_definition_cred_endpoint_query.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_efs_fileshare_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_efs_fileshare_mount_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_eks_cluster_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_elasticache_security_group_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_elasticache_security_group_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_enum_buckets.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_guardduty_disruption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_iam_backdoor_users_keys.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_iam_s3browser_loginprofile_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_iam_s3browser_templated_s3_bucket_policy_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_iam_s3browser_user_or_accesskey_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_passed_role_to_glue_development_endpoint.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_rds_change_master_password.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_rds_public_db_restore.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_root_account_usage.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_route_53_domain_transferred_lock_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_route_53_domain_transferred_to_another_account.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_s3_data_management_tampering.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_securityhub_finding_evasion.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_snapshot_backup_exfiltration.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_sso_idp_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_sts_assumerole_misuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_sts_getsessiontoken_misuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_susp_saml_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.aws.cloudtrail\aws_update_login_profile.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_aadhybridhealth_adfs_new_server.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_aadhybridhealth_adfs_service_delete.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_aad_secops_ca_policy_removedby_bad_actor.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_aad_secops_new_ca_policy_addedby_bad_actor.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_account_lockout.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_account_created_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_authentications_from_countries_you_do_not_operate_out_of.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_auth_failure_increase.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_auth_sucess_increase.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_auth_to_important_apps_using_single_factor_auth.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_azurehound_discovery.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_bitlocker_key_retrieval.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_device_registration_or_join_without_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_device_registration_policy_changes.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_failed_auth_from_countries_you_do_not_operate_out_of.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_guest_users_invited_to_tenant_by_non_approved_inviters.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_only_single_factor_auth_required.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_risky_sign_ins_with_singlefactorauth_from_unknown_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_sign_ins_from_noncompliant_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_sign_ins_from_unknown_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_suspicious_signin_bypassing_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_users_added_to_device_admin_roles.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_ad_user_added_to_admin_role.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_application_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_application_gateway_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_application_security_group_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_appid_uri_changes.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_credential_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_credential_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_delegated_permissions_all_users.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_device_code_authentication.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_end_user_consent.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_end_user_consent_blocked.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_owner_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_permissions_msft.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_privileged_permissions.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_role_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_ropc_authentication.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_app_uri_modifications.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_blocked_account_attempt.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_change_to_authentication_method.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_conditional_access_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_container_registry_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_device_no_longer_managed_or_compliant.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_device_or_configuration_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_dns_zone_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_federation_modified.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_firewall_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_firewall_rule_collection_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_group_user_addition_ca_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_group_user_removal_ca_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_guest_invite_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_guest_to_member.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_keyvault_key_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_keyvault_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_keyvault_secrets_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_admission_controller.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_cluster_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_cronjob.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_events_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_network_policy_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_pods_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_rolebinding_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_role_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_secret_or_config_object_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_kubernetes_service_account_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_legacy_authentication_protocols.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_login_to_disabled_account.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_mfa_denies.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_mfa_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_mfa_interrupted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_network_firewall_policy_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_network_firewall_rule_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_network_p2s_vpn_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_network_security_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_network_virtual_device_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_new_cloudshell_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_owner_removed_from_application_or_service_principal.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_pim_activation_approve_deny.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_pim_alerts_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_pim_change_settings.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_priviledged_role_assignment_add.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_priviledged_role_assignment_bulk_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_privileged_account_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_service_principal_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_service_principal_removed.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_subscription_permissions_elevation_via_activitylogs.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_subscription_permissions_elevation_via_auditlogs.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_suppression_rule_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_tap_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_unusual_authentication_interruption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_users_authenticating_to_other_azure_ad_tenants.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_user_login_blocked_by_conditional_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_user_password_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_virtual_network_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure\azure_vpn_connection_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_aadhybridhealth_adfs_new_server.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_aadhybridhealth_adfs_service_delete.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_ad_user_added_to_admin_role.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_application_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_application_gateway_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_application_security_group_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_app_credential_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_container_registry_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_device_no_longer_managed_or_compliant.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_device_or_configuration_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_dns_zone_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_firewall_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_firewall_rule_collection_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_keyvault_key_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_keyvault_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_keyvault_secrets_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_admission_controller.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_cluster_created_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_cronjob.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_events_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_network_policy_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_pods_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_rolebinding_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_role_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_secret_or_config_object_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_kubernetes_service_account_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_mfa_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_network_firewall_policy_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_network_firewall_rule_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_network_p2s_vpn_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_network_security_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_network_virtual_device_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_new_cloudshell_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_owner_removed_from_application_or_service_principal.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_service_principal_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_service_principal_removed.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_subscription_permissions_elevation_via_activitylogs.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_suppression_rule_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_virtual_network_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.activity_logs\azure_vpn_connection_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_aad_secops_ca_policy_removedby_bad_actor.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_aad_secops_new_ca_policy_addedby_bad_actor.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_ad_account_created_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_ad_bitlocker_key_retrieval.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_ad_device_registration_policy_changes.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_ad_guest_users_invited_to_tenant_by_non_approved_inviters.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_ad_users_added_to_device_admin_roles.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_appid_uri_changes.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_credential_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_delegated_permissions_all_users.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_end_user_consent.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_end_user_consent_blocked.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_owner_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_permissions_msft.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_privileged_permissions.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_role_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_app_uri_modifications.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_change_to_authentication_method.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_federation_modified.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_group_user_addition_ca_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_group_user_removal_ca_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_guest_invite_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_guest_to_member.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_pim_activation_approve_deny.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_pim_alerts_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_pim_change_settings.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_priviledged_role_assignment_add.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_priviledged_role_assignment_bulk_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_privileged_account_creation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_subscription_permissions_elevation_via_auditlogs.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_tap_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.audit_logs\azure_user_password_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_anomalous_token.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_anomalous_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_anonymous_ip_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_anonymous_ip_address.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_atypical_travel.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_impossible_travel.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_inbox_forwarding_rule.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_inbox_manipulation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_leaked_credentials.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_malicious_ip_address.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_malicious_ip_address_suspicious.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_malware_linked_ip.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_new_coutry_region.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_password_spray.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_prt_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_suspicious_browser.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_threat_intel.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_token_issuer_anomaly.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.identity_protection\azure_identity_protection_unfamilar_sign_in.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_account_stale.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_invalid_license.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_role_assigned_outside_of_pim.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_role_frequent_activation.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_role_not_used.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_role_no_mfa_required.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.privileged_identity_management\azure_pim_too_many_global_admins.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_account_lockout.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_authentications_from_countries_you_do_not_operate_out_of.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_auth_failure_increase.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_auth_sucess_increase.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_auth_to_important_apps_using_single_factor_auth.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_azurehound_discovery.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_device_registration_or_join_without_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_failed_auth_from_countries_you_do_not_operate_out_of.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_only_single_factor_auth_required.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_risky_sign_ins_with_singlefactorauth_from_unknown_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_sign_ins_from_noncompliant_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_sign_ins_from_unknown_devices.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_ad_suspicious_signin_bypassing_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_app_device_code_authentication.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_app_ropc_authentication.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_blocked_account_attempt.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_conditional_access_failure.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_legacy_authentication_protocols.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_login_to_disabled_account.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_mfa_denies.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_mfa_interrupted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_unusual_authentication_interruption.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_users_authenticating_to_other_azure_ad_tenants.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.azure.signin_logs\azure_user_login_blocked_by_conditional_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_bucket_enumeration.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_bucket_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_dlp_re_identifies_sensitive_information.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_dns_zone_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_firewall_rule_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_full_network_traffic_packet_capture.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_kubernetes_admission_controller.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_kubernetes_cronjob.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_kubernetes_rolebinding.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_kubernetes_secrets_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_service_account_disabled_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_service_account_modified.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_sql_database_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp\gcp_vpn_tunnel_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_bucket_enumeration.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_bucket_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_dlp_re_identifies_sensitive_information.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_dns_zone_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_firewall_rule_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_full_network_traffic_packet_capture.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_kubernetes_admission_controller.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_kubernetes_cronjob.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_kubernetes_rolebinding.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_kubernetes_secrets_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_service_account_disabled_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_service_account_modified.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_sql_database_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.audit\gcp_vpn_tunnel_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_application_removed.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_granted_domain_api_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_mfa_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_role_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_role_privilege_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gcp.gworkspace\gcp_gworkspace_user_granted_admin_privileges.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_delete_action_invoked.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_disabled_outdated_dependency_or_vulnerability.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_disable_high_risk_configuration.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_new_org_member.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_new_secret_created.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_outside_collaborator_detected.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.github\github_self_hosted_runner_changes_detected.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_application_removed.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_granted_domain_api_access.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_mfa_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_role_modified_or_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_role_privilege_deleted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.gworkspace\gworkspace_user_granted_admin_privileges.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_activity_by_terminated_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_activity_from_anonymous_ip_addresses.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_activity_from_infrequent_country.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_data_exfiltration_to_unsanctioned_app.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_disabling_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_from_susp_ip_addresses.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_impossible_travel_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_logon_from_risky_ip_address.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_new_federated_domain_added.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_new_federated_domain_added_audit.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_new_federated_domain_added_exchange.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_potential_ransomware_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_pst_export_alert.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_pst_export_alert_using_new_compliancesearchaction.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_susp_inbox_forwarding.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_susp_oauth_app_file_download_activities.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_unusual_volume_of_file_deletion.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365\microsoft365_user_restricted_from_sending_email.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.audit\microsoft365_disabling_mfa.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.audit\microsoft365_new_federated_domain_added_audit.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.exchange\microsoft365_new_federated_domain_added_exchange.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_detection\microsoft365_from_susp_ip_addresses.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_activity_by_terminated_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_activity_from_anonymous_ip_addresses.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_activity_from_infrequent_country.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_data_exfiltration_to_unsanctioned_app.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_impossible_travel_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_logon_from_risky_ip_address.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_potential_ransomware_activity.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_pst_export_alert.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_pst_export_alert_using_new_compliancesearchaction.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\cloud.m365.threat_management\microsoft365_susp_inbox_forwarding.kql
# ...
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_evtx_file_key_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_exploit_guard_susp_allowed_apps.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_fax_change_service_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_fax_dll_persistance.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_file_association_exefile.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hangs_debugger_persistence.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hhctrl_persistence.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hidden_extention.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hide_file.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hide_function_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_hide_scheduled_task_via_index_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_ie_security_zone_protocol_defaults_downgrade.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_install_root_or_ca_certificat.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_internet_explorer_disable_first_run_customize.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_legalnotice_susp_message.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_lolbin_onedrivestandaloneupdater.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_lsass_usermode_dumping.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_lsa_disablerestrictedadmin.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_mal_adwind.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_mal_blue_mockingbird.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_net_cli_ngenassemblyusagelog.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_new_application_appcompat.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_new_network_provider.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_odbc_driver_registered.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_odbc_driver_registered_susp.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_access_vbom_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_disable_protected_view_features.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_enable_dde.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_outlook_enable_load_macro_provider_on_boot.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_outlook_enable_macro_execution.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_outlook_enable_unsafe_client_mail_rules.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_outlook_security_settings.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_trusted_location_uncommon.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_trust_record_susp_location.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_office_vba_warnings_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_appx_debugger.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_app_paths.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_autodial_dll.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_chm.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_comhijack_psfactorybuffer.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_com_hijacking_susp_locations.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_custom_protocol_handler.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_event_viewer_events_asp.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_globalflags.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_ie.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_ifilter.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_lsa_extension.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_mpnotify.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_mycomputer.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_natural_language.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_office_vsto.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_outlook_homepage.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_outlook_todaypage.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_reflectdebugger.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_scrobj_dll.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_search_order.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_shim_database.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_shim_database_susp_application.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_shim_database_uncommon_location.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_typed_paths.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_persistence_xll.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_policies_associations_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_policies_attachments_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_powershell_as_service.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_powershell_enablescripts_enabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_powershell_execution_policy.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_powershell_in_run_keys.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_powershell_logging_disabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_provisioning_command_abuse.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_renamed_sysinternals_eula_accepted.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_rpcrt4_etw_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_scr_file_executed_by_rundll32.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_servicedll_hijack.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_services_etw_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_set_nopolicies_user.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_sip_persistence.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_sophos_av_tamper.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_special_accounts.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_suppress_defender_notifications.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_suspicious_env_variables.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_keyboard_layout_load.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_pendingfilerenameoperations.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_printer_driver.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_reg_persist_explorer_run.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_run_key_img_folder.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_service_installed.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_susp_user_shell_folders.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_taskcache_entry.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_telemetry_persistence.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_terminal_server_suspicious.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_terminal_server_tampering.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_timeproviders_dllname.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_tls_protocol_old_version_enabled.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_treatas_persistence.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_turn_on_dev_features.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_uac_bypass_eventvwr.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_uac_bypass_sdclt.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_uac_bypass_winsat.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_uac_bypass_wmp.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_vbs_payload_stored.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_wab_dllpath_reg_change.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_wdigest_enable_uselogoncredential.kql
# Error saving registry_set_windows_defender_tamper.yml ('WindowsPath' object is not subscriptable)
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_winget_admin_settings_tampering.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_winget_enable_local_manifest.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_winlogon_allow_multiple_tssessions.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.registry.registry_set\registry_set_winlogon_notify_key.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_config_modification.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_config_modification_error.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_config_modification_status.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_file_block_exe.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_file_block_executable.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_file_block_shredding.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_file_executable.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_file_executable_detected.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.sysmon\sysmon_process_hollowing.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.wmi_event\sysmon_wmi_event_subscription.kql
# Saved c:\Users\cseelhoff\source\repos\auto-rule-enabler_kql_out\windows.wmi_event\sysmon_wmi_susp_scripting.kql
